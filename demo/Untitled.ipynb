# %%
import cv2
import numpy as np
from model_func import Face_Model

facec = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
font = cv2.FONT_HERSHEY_SIMPLEX
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
model_dir = '../face_models/'
face_model = Face_Model(model_dir, 'vggFace_finetune_val_loss_FER.json', 'vggFace_finetune_val_loss_1.105_63.1_FER.h5')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0813 14:37:25.983186 31552 deprecation_wrapper.py:119] From C:\Users\Susan\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0813 14:37:26.047646 31552 deprecation_wrapper.py:119] From C:\Users\Susan\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0813 14:37:26.094527 31552 deprecation_wrapper.py:119] From C:\Users\Susan\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0813 14:37:26.095881 31552 deprecation_wrapper.py:119] From C:\Users\Susan\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0813 14:37:26.096878 31552 deprecation_wrapper.py:119] From C:\Users\Susan\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0813 14:37:26.166898 31552 deprecation_wrapper.py:119] From C:\Users\Susan\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# ../face_models/vggFace_finetune_val_loss_FER.json
# W0813 14:37:26.287005 31552 deprecation_wrapper.py:119] From C:\Users\Susan\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0813 14:37:34.459162 31552 deprecation_wrapper.py:119] From C:\Users\Susan\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
import pickle as pkl
import matplotlib.pyplot as plt

# %%
with open ('vid_np.pkl', 'rb') as f:
    vid = pkl.load(f)

# %%
plt.imshow(vid[0, :, :])

# %%
face_model.predict_emotion_class(vid)
# Out:
#  [[[[193 188 181]
#    [193 188 181]
#    [194 188 180]
#    ...
#    [209 204 197]
#    [206 204 195]
#    [204 204 194]]
#
#   [[193 188 181]
#    [193 188 181]
#    [194 188 180]
#    ...
#    [208 203 196]
#    [205 202 194]
#    [202 202 192]]
#
#   [[193 188 181]
#    [193 188 181]
#    [194 188 180]
#    ...
#    [206 201 195]
#    [202 200 192]
#    [199 199 190]]
#
#   ...
#
#   [[ 81  55  47]
#    [ 79  52  45]
#    [ 78  49  44]
#    ...
#    [ 79  30  32]
#    [ 79  30  31]
#    [ 78  29  31]]
#
#   [[ 83  58  50]
#    [ 81  54  47]
#    [ 78  50  45]
#    ...
#    [ 79  30  32]
#    [ 79  30  32]
#    [ 78  30  32]]
#
#   [[ 86  62  54]
#    [ 82  56  50]
#    [ 78  51  46]
#    ...
#    [ 80  31  33]
#    [ 79  31  33]
#    [ 78  31  33]]]]
# 'Surprise'
